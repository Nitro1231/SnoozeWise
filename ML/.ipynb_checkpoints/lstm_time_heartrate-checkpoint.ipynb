# %%
# ! pip install imbalanced-learn
# ! pip install --force-reinstall 'scikit-learn==0.19.2' 
# ! pip install pickle-mixin
# ! pip install --force-reinstall 'scikit-learn==0.19.2'

# %%
import math
import json
import pickle
import numpy as np
import pandas as pd
import coremltools as ct
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from collections import defaultdict

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import matplotlib.pyplot as plt
# Out:
# WARNING:root:TensorFlow version 2.6.2 detected. Last version known to be fully compatible is 2.3.1 .
# WARNING:root:Keras version 2.6.0 detected. Last version known to be fully compatible of Keras is 2.2.4 .

# %%
STAGE = {
    'In Bed': 0,
    'Awake': 1,
    'Asleep': 2,
    'REM': 3,
    'Core': 4,
    'Deep': 5,
    'Unknown': 6
}

# %%
def load_json(path: str) -> dict:
    with open(path, 'r') as file:
        return json.load(file)

def parse_time(time: str) -> datetime:
    return datetime.strptime(time, '%Y-%m-%d %H:%M:%S')

def to_min(cur_time: datetime, start_time: datetime) -> int:
    return int((cur_time - start_time).total_seconds()//60)

def process_sleep_data(sleep_data: dict) -> dict:
    stages_by_day = defaultdict(dict)

    for data in sleep_data:
        if data['stage'] in ['Awake', 'REM', 'Core', 'Deep']:
            start_time = parse_time(data['start_time'])
            end_time = parse_time(data['end_time'])
            day = end_time.strftime('%Y-%m-%d')

            if not day in stages_by_day:
                stages_by_day[day]['stages'] = list()
                
            stages_by_day[day]['stages'].append({
                'start_time': start_time,
                'end_time': end_time,
                'stage': STAGE[data['stage']]
            })

    for date, data in stages_by_day.items():
        stages_by_day[date]['stages'] = sorted(data['stages'], key=lambda x: x['start_time'])
        stages_by_day[date]['start_time'] = stages_by_day[date]['stages'][0]['start_time']
        stages_by_day[date]['end_time'] = stages_by_day[date]['stages'][-1]['end_time']
        stages_by_day[date]['day_of_week'] = stages_by_day[date]['start_time'].weekday()

    return stages_by_day

def process_heart_rate_data(heart_rate_data: dict, stage_data: dict)  -> dict:
    for data in heart_rate_data:
        start_time = parse_time(data['startDate'])
        end_time = parse_time(data['endDate'])
        day = end_time.strftime('%Y-%m-%d')
        
        if day in stage_data and (stage_data[day]['start_time'] <= start_time and end_time <= stage_data[day]['end_time']):
            if 'heart_rate_intervals' not in stage_data[day]:
                stage_data[day]['heart_rate_intervals'] = []
            stage_data[day]['heart_rate_intervals'].append({
                'start_time': start_time,
                'end_time': end_time,
                'bpm': data['bpm']
            })

    for data in stage_data.values():
        if 'heart_rate_intervals' not in data:
            data['heart_rate_intervals'] = []
            
        data['heart_rate_intervals'] = sorted(data['heart_rate_intervals'], key=lambda x: x['start_time'])
    
    return stage_data

def post_process(stage_data: dict) -> pd.DataFrame:
    def find_closest_heart_rate(heart_rate_intervals, timestamp):
        closest_hr = None
        min_difference = float('inf')

        for hr in heart_rate_intervals:
            start, end, heart_rate = hr['start_time'], hr['end_time'], hr['bpm']
            
            if start <= timestamp <= end:
                return heart_rate
            
            difference = min(abs(start - timestamp), abs(end - timestamp))
            if difference.seconds < min_difference:
                min_difference = difference.seconds
                closest_hr = heart_rate

        return closest_hr

    ml_data = list()
    for date, data in stage_data.items():
       
        for interval,item in enumerate(data['stages']):  # sorted ascendingly
            
            heart_rate_intervals = [d for d in data['heart_rate_intervals'] if (item['start_time'] <= d['start_time'] and d['end_time'] <= item['end_time'])]
            if len(heart_rate_intervals) == 0:
                continue
                
            timeline = []
            current_time = item['start_time']
            while current_time < item['end_time']:
                heart_rate = find_closest_heart_rate(heart_rate_intervals, current_time)
                timeline.append(heart_rate)
                current_time += timedelta(minutes=1)
            
            stime = item['start_time'].time()
            stime_in_min = stime.hour*60 + stime.minute
            etime = item['end_time'].time()
            etime_in_min = etime.hour*60 + etime.minute
            
            desired_size = 159
            hri = timeline + [0] * (desired_size - len(timeline))
            
            if any(v != 0 for v in hri):
                ml_data.append((
                    stime_in_min,
                    etime_in_min,
                    interval,
                    item['stage'],
                    hri
                ))
    return pd.DataFrame(ml_data, columns=['start_time', 'end_time', 'time_step', 'stage', 'heart_rate_intervals'])

# %%
sleep_data = load_json('./sleepData.json')['sleep_data']
stage_data = process_sleep_data(sleep_data)

# %%
heart_rate_data = load_json('./filteredHeartRate.json')
total_data = process_heart_rate_data(heart_rate_data, stage_data)

# %%
ml_data = post_process(total_data)

# %%
print(ml_data.head())
ml_data.info()
# Out:
#    start_time  end_time  time_step  stage  \
# 0         113       127          0      4
# 1         127       145          1      5
# 2         145       157          2      4
# 3         157       167          3      5
# 4         167       172          4      4
#
#                                 heart_rate_intervals
# 0  [97, 97, 97, 97, 97, 93, 93, 107.0000000000000...
# 1  [141, 145, 152, 156, 157, 155, 156, 159, 161, ...
# 2  [164, 163, 165, 166, 167, 168, 169.00000000000...
# 3  [120, 118, 114, 153, 165, 165, 166, 158, 132, ...
# 4  [115, 116, 151, 159, 161, 0, 0, 0, 0, 0, 0, 0,...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6277 entries, 0 to 6276
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   start_time            6277 non-null   int64
#  1   end_time              6277 non-null   int64
#  2   time_step             6277 non-null   int64
#  3   stage                 6277 non-null   int64
#  4   heart_rate_intervals  6277 non-null   object
# dtypes: int64(4), object(1)
# memory usage: 245.3+ KB

# %%
# len(max(ml_data['heart_rate_intervals'].values, key=lambda x: len(x)))
ml_data['interval_size'] = ml_data['end_time'] - ml_data['start_time']
# ml_data['interval_size'].max()
# ml_data.iloc[:100]
# type(ml_data.iloc[0]['heart_rate_intervals'][0])

# print(any(ml_data[ml_data.isnull().any(axis=1)]))
# len(ml_data[ml_data.isnull().any(axis=1)])

# for i in range(1):
#     print(ml_data.iloc[i]['interval_size'], len(ml_data.iloc[i]['heart_rate_intervals']), ml_data.iloc[i]['heart_rate_intervals'])

ml_data.iloc[0]
# Out:
# start_time                                                            113
# end_time                                                              127
# time_step                                                               0
# stage                                                                   4
# heart_rate_intervals    [97, 97, 97, 97, 97, 93, 93, 107.0000000000000...
# interval_size                                                          14
# Name: 0, dtype: object

# %%
# X = ml_data[['start_time', 'end_time', 'time_step', 'stage']].values.astype('float32')
# Y = np.vstack(ml_data['heart_rate_intervals'].values).astype('float32')

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1) # reshape X data into 3-dim for LSTM
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# print(X.shape, X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)


# model = tf.keras.Sequential([
#     tf.keras.layers.LSTM(64, return_sequences=False, input_shape=(X.shape[1], 1)),
#     tf.keras.layers.Dense(159)
# ])

# # model = tf.keras.Sequential([
# #     tf.keras.layers.LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
# #     tf.keras.layers.BatchNormalization(),
# #     tf.keras.layers.Dropout(0.3),
# #     tf.keras.layers.LSTM(128, return_sequences=False),
# #     tf.keras.layers.BatchNormalization(),
# #     tf.keras.layers.Dropout(0.3),
# #     tf.keras.layers.Dense(256, activation='relu'),
# #     tf.keras.layers.BatchNormalization(),
# #     tf.keras.layers.Dropout(0.3),
# #     tf.keras.layers.Dense(159)  # Output layer with 1620 neurons for regression
# # ])


# model.compile(optimizer='adam', loss='mse')
# model.fit(X_train, Y_train, epochs=40, batch_size=128, validation_split=0.2)


# loss = model.evaluate(X_test, Y_test)
# print("Test Loss:", loss)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, BatchNormalization, Dropout
import numpy as np

X = ml_data[['start_time', 'end_time', 'time_step', 'stage']].values.astype('float32')
Y = np.vstack(ml_data['heart_rate_intervals'].values).astype('float32')

# Splitting the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Reshape data for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Model definition
model = Sequential([
    LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(128, return_sequences=False),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(159)  
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=1e-7)

# Model training with early stopping
history = model.fit(X_train, Y_train, epochs=100, batch_size=128, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 32/32 [==============================] - 4s 39ms/step - loss: 624.0810 - val_loss: 627.9417
# Epoch 2/100
# 32/32 [==============================] - 1s 23ms/step - loss: 608.4380 - val_loss: 631.4316
# Epoch 3/100
# 32/32 [==============================] - 1s 23ms/step - loss: 585.2337 - val_loss: 642.7229
# Epoch 4/100
# 32/32 [==============================] - 1s 23ms/step - loss: 541.8714 - val_loss: 586.9958
# Epoch 5/100
# 32/32 [==============================] - 1s 22ms/step - loss: 481.6996 - val_loss: 595.5155
# Epoch 6/100
# 32/32 [==============================] - 1s 23ms/step - loss: 417.0542 - val_loss: 427.6320
# Epoch 7/100
# 32/32 [==============================] - 1s 24ms/step - loss: 355.6809 - val_loss: 313.2272
# Epoch 8/100
# 32/32 [==============================] - 1s 26ms/step - loss: 293.4104 - val_loss: 267.4754
# Epoch 9/100
# 32/32 [==============================] - 1s 27ms/step - loss: 245.2186 - val_loss: 300.2997
# Epoch 10/100
# 32/32 [==============================] - 1s 26ms/step - loss: 208.8874 - val_loss: 330.8543
# Epoch 11/100
# 32/32 [==============================] - 1s 24ms/step - loss: 186.1198 - val_loss: 220.2196
# Epoch 12/100
# 32/32 [==============================] - 1s 24ms/step - loss: 169.3227 - val_loss: 342.4545
# Epoch 13/100
# 32/32 [==============================] - 1s 23ms/step - loss: 154.1365 - val_loss: 176.1104
# Epoch 14/100
# 32/32 [==============================] - 1s 24ms/step - loss: 166.8290 - val_loss: 164.5070
# Epoch 15/100
# 32/32 [==============================] - 1s 23ms/step - loss: 145.3871 - val_loss: 225.1130
# Epoch 16/100
# 32/32 [==============================] - 1s 24ms/step - loss: 141.2959 - val_loss: 280.8436
# Epoch 17/100
# 32/32 [==============================] - 1s 23ms/step - loss: 134.3514 - val_loss: 141.4419
# Epoch 18/100
# 32/32 [==============================] - 1s 23ms/step - loss: 150.1336 - val_loss: 593.4388
# Epoch 19/100
# 32/32 [==============================] - 1s 24ms/step - loss: 135.3770 - val_loss: 127.5358
# Epoch 20/100
# 32/32 [==============================] - 1s 24ms/step - loss: 135.6820 - val_loss: 112.2147
# Epoch 21/100
# 32/32 [==============================] - 1s 24ms/step - loss: 133.7066 - val_loss: 122.8029
# Epoch 22/100
# 32/32 [==============================] - 1s 24ms/step - loss: 124.0843 - val_loss: 121.6260
# Epoch 23/100
# 32/32 [==============================] - 1s 24ms/step - loss: 119.9629 - val_loss: 218.1042
# Epoch 24/100
# 32/32 [==============================] - 1s 24ms/step - loss: 121.9473 - val_loss: 200.4267
# Epoch 25/100
# 32/32 [==============================] - 1s 25ms/step - loss: 120.0049 - val_loss: 158.9422
# Epoch 26/100
# 32/32 [==============================] - 1s 24ms/step - loss: 118.4064 - val_loss: 318.5430
# Epoch 27/100
# 32/32 [==============================] - 1s 23ms/step - loss: 125.9544 - val_loss: 585.6644
# Epoch 28/100
# 32/32 [==============================] - 1s 23ms/step - loss: 115.1576 - val_loss: 109.4976
# Epoch 29/100
# 32/32 [==============================] - 1s 23ms/step - loss: 109.9619 - val_loss: 101.4984
# Epoch 30/100
# 32/32 [==============================] - 1s 24ms/step - loss: 109.5485 - val_loss: 197.2093
# Epoch 31/100
# 32/32 [==============================] - 1s 24ms/step - loss: 105.4682 - val_loss: 133.5928
# Epoch 32/100
# 32/32 [==============================] - 1s 24ms/step - loss: 104.6510 - val_loss: 186.2845
# Epoch 33/100
# 32/32 [==============================] - 1s 24ms/step - loss: 108.2304 - val_loss: 330.1259
# Epoch 34/100
# 32/32 [==============================] - 1s 24ms/step - loss: 103.1982 - val_loss: 227.2867
# Epoch 35/100
# 32/32 [==============================] - 1s 24ms/step - loss: 107.7910 - val_loss: 123.3464
# Epoch 36/100
# 32/32 [==============================] - 1s 24ms/step - loss: 105.7204 - val_loss: 89.2037
# Epoch 37/100
# 32/32 [==============================] - 1s 24ms/step - loss: 106.7082 - val_loss: 91.3344
# Epoch 38/100
# 32/32 [==============================] - 1s 24ms/step - loss: 105.7080 - val_loss: 198.2149
# Epoch 39/100
# 32/32 [==============================] - 1s 24ms/step - loss: 104.6642 - val_loss: 114.9813
# Epoch 40/100
# 32/32 [==============================] - 1s 24ms/step - loss: 104.7633 - val_loss: 220.3460
# Epoch 41/100
# 32/32 [==============================] - 1s 24ms/step - loss: 102.7471 - val_loss: 159.2860
# Epoch 42/100
# 32/32 [==============================] - 1s 24ms/step - loss: 101.4761 - val_loss: 192.6241
# Epoch 43/100
# 32/32 [==============================] - 1s 24ms/step - loss: 102.6203 - val_loss: 87.2847
# Epoch 44/100
# 32/32 [==============================] - 1s 24ms/step - loss: 100.2954 - val_loss: 88.9806
# Epoch 45/100
# 32/32 [==============================] - 1s 23ms/step - loss: 97.9667 - val_loss: 118.2562
# Epoch 46/100
# 32/32 [==============================] - 1s 23ms/step - loss: 99.1904 - val_loss: 148.5825
# Epoch 47/100
# 32/32 [==============================] - 1s 24ms/step - loss: 103.2664 - val_loss: 445.2922
# Epoch 48/100
# 32/32 [==============================] - 1s 24ms/step - loss: 100.7758 - val_loss: 115.9876
# Epoch 49/100
# 32/32 [==============================] - 1s 24ms/step - loss: 100.7261 - val_loss: 93.8154
# Epoch 50/100
# 32/32 [==============================] - 1s 26ms/step - loss: 99.8649 - val_loss: 131.8495
# Epoch 51/100
# 32/32 [==============================] - 1s 24ms/step - loss: 98.0371 - val_loss: 96.7452
# Epoch 52/100
# 32/32 [==============================] - 1s 25ms/step - loss: 96.2113 - val_loss: 81.8919
# Epoch 53/100
# 32/32 [==============================] - 1s 24ms/step - loss: 96.9810 - val_loss: 137.8108
# Epoch 54/100
# 32/32 [==============================] - 1s 24ms/step - loss: 96.2551 - val_loss: 89.3945
# Epoch 55/100
# 32/32 [==============================] - 1s 24ms/step - loss: 95.3264 - val_loss: 134.1670
# Epoch 56/100
# 32/32 [==============================] - 1s 24ms/step - loss: 95.7148 - val_loss: 104.2799
# Epoch 57/100
# 32/32 [==============================] - 1s 23ms/step - loss: 95.7783 - val_loss: 104.8672
# Epoch 58/100
# 32/32 [==============================] - 1s 23ms/step - loss: 96.8240 - val_loss: 102.3524
# Epoch 59/100
# 32/32 [==============================] - 1s 23ms/step - loss: 95.1080 - val_loss: 118.1205
# Epoch 60/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.2694 - val_loss: 79.6041
# Epoch 61/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.7617 - val_loss: 90.0666
# Epoch 62/100
# 32/32 [==============================] - 1s 24ms/step - loss: 91.8488 - val_loss: 81.8899
# Epoch 63/100
# 32/32 [==============================] - 1s 26ms/step - loss: 95.7442 - val_loss: 81.3229
# Epoch 64/100
# 32/32 [==============================] - 1s 25ms/step - loss: 95.4055 - val_loss: 81.6083
# Epoch 65/100
# 32/32 [==============================] - 1s 25ms/step - loss: 96.1887 - val_loss: 85.3912
# Epoch 66/100
# 32/32 [==============================] - 1s 25ms/step - loss: 94.6711 - val_loss: 84.4636
# Epoch 67/100
# 32/32 [==============================] - 1s 24ms/step - loss: 92.8168 - val_loss: 82.6506
# Epoch 68/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.6009 - val_loss: 79.4522
# Epoch 69/100
# 32/32 [==============================] - 1s 24ms/step - loss: 94.0527 - val_loss: 79.5381
# Epoch 70/100
# 32/32 [==============================] - 1s 24ms/step - loss: 94.6147 - val_loss: 79.3524
# Epoch 71/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.6283 - val_loss: 79.8367
# Epoch 72/100
# 32/32 [==============================] - 1s 24ms/step - loss: 94.6035 - val_loss: 79.4923
# Epoch 73/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.4372 - val_loss: 80.0989
# Epoch 74/100
# 32/32 [==============================] - 1s 24ms/step - loss: 92.6946 - val_loss: 79.5622
# Epoch 75/100
# 32/32 [==============================] - 1s 24ms/step - loss: 94.9607 - val_loss: 79.5952
# Epoch 76/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.5040 - val_loss: 80.1565
# Epoch 77/100
# 32/32 [==============================] - 1s 24ms/step - loss: 93.7831 - val_loss: 79.3761
# Epoch 78/100
# 32/32 [==============================] - 1s 26ms/step - loss: 94.0827 - val_loss: 79.3687
# Epoch 79/100
# 32/32 [==============================] - 1s 31ms/step - loss: 95.5494 - val_loss: 79.4044
# Epoch 80/100
# 32/32 [==============================] - 1s 39ms/step - loss: 94.4920 - val_loss: 79.4482
# Epoch 81/100
# 32/32 [==============================] - 2s 49ms/step - loss: 92.9177 - val_loss: 79.4373
# Epoch 82/100
# 32/32 [==============================] - 1s 44ms/step - loss: 94.7627 - val_loss: 79.3884
# Epoch 83/100
# 32/32 [==============================] - 1s 26ms/step - loss: 93.8615 - val_loss: 79.4038
# Epoch 84/100
# 32/32 [==============================] - 1s 24ms/step - loss: 95.1331 - val_loss: 79.3362
# Epoch 85/100
# 32/32 [==============================] - 1s 25ms/step - loss: 93.0985 - val_loss: 79.4629
# Epoch 86/100
# 32/32 [==============================] - 1s 26ms/step - loss: 94.9610 - val_loss: 79.3449
# Epoch 87/100
# 32/32 [==============================] - 1s 27ms/step - loss: 94.9683 - val_loss: 79.3076
# Epoch 88/100
# 32/32 [==============================] - 1s 28ms/step - loss: 92.9212 - val_loss: 79.4156
# Epoch 89/100
# 32/32 [==============================] - 1s 25ms/step - loss: 93.3983 - val_loss: 79.3683
# Epoch 90/100
# 32/32 [==============================] - 1s 27ms/step - loss: 95.4054 - val_loss: 79.3398
# Epoch 91/100
# 32/32 [==============================] - 1s 27ms/step - loss: 94.9283 - val_loss: 79.3800
# Epoch 92/100
# 32/32 [==============================] - 1s 26ms/step - loss: 93.9016 - val_loss: 79.3850
# Epoch 93/100
# 32/32 [==============================] - 1s 25ms/step - loss: 94.0807 - val_loss: 79.3692
# Epoch 94/100
# 32/32 [==============================] - 1s 25ms/step - loss: 94.9044 - val_loss: 79.3495
# Epoch 95/100
# 32/32 [==============================] - 1s 26ms/step - loss: 95.1115 - val_loss: 79.3354
# Epoch 96/100
# 32/32 [==============================] - 1s 25ms/step - loss: 92.9328 - val_loss: 79.3531
# Epoch 97/100
# 32/32 [==============================] - 1s 24ms/step - loss: 94.8605 - val_loss: 79.3601
# Epoch 98/100
# 32/32 [==============================] - 1s 26ms/step - loss: 92.7711 - val_loss: 79.3397
# Epoch 99/100
# 32/32 [==============================] - 1s 25ms/step - loss: 94.4450 - val_loss: 79.3760
# Epoch 100/100
# 32/32 [==============================] - 1s 26ms/step - loss: 92.1363 - val_loss: 79.3544

# %%
loss = model.evaluate(X_test, Y_test)
print("Test Loss:", loss)
# Out:
# 40/40 [==============================] - 0s 5ms/step - loss: 83.7570
# Test Loss: 83.75704193115234

# %%
print(X_test.shape)
print(model.predict(X_test).shape)
# Out:
# (1256, 4, 1)
# (1256, 159)

# %%
import datetime

import random as r

idx = r.randint(0, X_test.shape[0] - 1)
predictions = model.predict(X_test)[idx].astype(int)
t = ml_data[ (ml_data['start_time'] == int(X_test[idx][0][0])) & (ml_data['end_time'] == int(X_test[idx][1][0]))].iloc[0]


# print(X_test[0], X_test[0][0][0], '\n',ml_data[ml_data['start_time'] == int(X_test[0][0][0])])

start_time = datetime.datetime.strptime('00:00', '%H:%M')
print(start_time + datetime.timedelta(minutes=int(t['start_time'])), start_time + datetime.timedelta(minutes=int(t['end_time'])))
ST = int(t['start_time'])

x = []
y = []
for i in range(t['interval_size']):
    start_date = start_time + datetime.timedelta(minutes=ST + i)
    bpm = predictions[i]
    
    x.append(start_date)
    y.append(bpm)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-', label='predicted')
plt.plot(x, t['heart_rate_intervals'][:t['interval_size']], marker='s', linestyle='--', color='r', label='true')
plt.xlabel('Date')
plt.ylabel('BPM')
plt.title('Predicted Heart Rate over Time')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# 1900-01-01 13:05:00 1900-01-01 13:40:00

# %%
coreml_model = ct.convert(
    model,
    inputs = [ct.TensorType(name="lstm_input", shape=(1,4,1))]
)
coreml_model.save("LSTMHeartRate.mlmodel")
# Out:
# Running TensorFlow Graph Passes: 100%|██████████| 5/5 [00:00<00:00,  7.07 passes/s]
# Converting Frontend ==> MIL Ops:   0%|          | 0/99 [00:00<?, ? ops/s]
# Converting Frontend ==> MIL Ops: 100%|██████████| 14/14 [00:00<00:00, 21114.80 ops/s]
#
# Converting Frontend ==> MIL Ops:   0%|          | 0/40 [00:00<?, ? ops/s]WARNING:root:Input ls elem type unknown. Override with <class 'coremltools.converters.mil.mil.types.type_tensor.tensor.<locals>.tensor'>
# Converting Frontend ==> MIL Ops: 100%|██████████| 40/40 [00:00<00:00, 5491.36 ops/s]
#
# Converting Frontend ==> MIL Ops: 100%|██████████| 14/14 [00:00<00:00, 14477.38 ops/s]
#
# Converting Frontend ==> MIL Ops:   0%|          | 0/40 [00:00<?, ? ops/s]WARNING:root:Input ls elem type unknown. Override with <class 'coremltools.converters.mil.mil.types.type_tensor.tensor.<locals>.tensor'>
# Converting Frontend ==> MIL Ops: 100%|██████████| 40/40 [00:00<00:00, 5229.32 ops/s]
#
# Converting Frontend ==> MIL Ops: 100%|██████████| 14/14 [00:00<00:00, 14877.19 ops/s]
#
# Converting Frontend ==> MIL Ops:   0%|          | 0/40 [00:00<?, ? ops/s]WARNING:root:Input ls elem type unknown. Override with <class 'coremltools.converters.mil.mil.types.type_tensor.tensor.<locals>.tensor'>
# Converting Frontend ==> MIL Ops: 100%|██████████| 40/40 [00:00<00:00, 5180.07 ops/s]
#
# Converting Frontend ==> MIL Ops: 100%|██████████| 14/14 [00:00<00:00, 17414.07 ops/s]
#
# Converting Frontend ==> MIL Ops:   0%|          | 0/40 [00:00<?, ? ops/s]WARNING:root:Input ls elem type unknown. Override with <class 'coremltools.converters.mil.mil.types.type_tensor.tensor.<locals>.tensor'>
# Converting Frontend ==> MIL Ops: 100%|██████████| 40/40 [00:00<00:00, 5258.33 ops/s]
# Converting Frontend ==> MIL Ops: 100%|██████████| 99/99 [00:00<00:00, 864.06 ops/s]
# Running MIL Common passes: 100%|██████████| 33/33 [00:00<00:00, 1371.05 passes/s]
# Running MIL Clean up passes: 100%|██████████| 8/8 [00:00<00:00, 1090.99 passes/s]
# Translating MIL ==> NeuralNetwork Ops:   0%|          | 0/97 [00:00<?, ? ops/s]
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 1/1 [00:00<00:00, 2256.22 ops/s]
#
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 24/24 [00:00<00:00, 633.23 ops/s]
#
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 1/1 [00:00<00:00, 2816.86 ops/s]
#
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 24/24 [00:00<00:00, 865.99 ops/s]
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 97/97 [00:00<00:00, 1053.81 ops/s]

# %%
model.save('LSTMHeartRateModel')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
